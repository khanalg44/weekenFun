# %%
import numpy as np
import pandas as pd

##!pip3 install xlrd

df = pd.read_excel('2020-AbstractSubmissionForm.xlsx')
df = df.fillna('NAN')
df.head(5)
# Out:
#                 Timestamp                  Email Address  \
# 0 2020-05-31 22:14:04.112      abiskarsubedi16@gmail.com
# 1 2020-06-01 13:07:46.638        karki.abishek@gmail.com
# 2 2020-05-27 12:04:22.272     shresthaagrima53@gmail.com
# 3 2020-05-30 09:40:22.470  alishabudhathoki100@gmail.com
# 4 2020-05-31 01:13:42.655         paudelahsila@gmail.com
#
#               Full Name                                Current Affiliation  \
# 0       Aabiskar Subedi              Prithivi Naryan Campus , M.Sc Physics
# 1         Abishek Karki                       Mississippi State University
# 2  Agrima Nana Shrestha                                       Ascol Campus
# 3     Alisha Budhathoki  Central Department of Physics, Tribhuvan Unive...
# 4         Alisha Paudel  Prithivi Narayan campus, Tribhuwan university ...
#
#      Phone Number           Author List   \
# 0      9846781416       Aabiskar Subedi
# 1      7572408021                    NAN
# 2      9840873691      Yenca Migoya Orue
# 3  +9779868331463  Madhav Prasad Ghimire
# 4      9840683727        Aabiskar Bhusal
#
#                                 Author Affiliation/s  \
# 0                             PrithiviNaryan Campus
# 1                                                NAN
# 2                                               ICTP
# 3  Central Department of Physics, Tribhuvan Unive...
# 4      Physics Research Initiatives, Pokhara , Nepal
#
#   What part of your information and presentation can we upload on our website?  \
# 0  Author Name/s; Title of the Presentation and A...
# 1  Author Name/s; Title of the Presentation and A...
# 2  Author Name/s; Title of the Presentation and A...
# 3                                 Author Name/s only
# 4        Author Name/s and Title of the Presentation
#
#   Do you want to publish your research in extended abstract/proceedings? If you answer 'Yes' and our selection committee approves, we will contact you later.   \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   We are planning to live telecast this event for authors who consent to it. Do you consent to live telecast your presentation?   \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#         Please choose field of your presentation  \
# 0  Condensed Matter Physics and Material Science
# 1     High Energy, Particle, and Nuclear Physics
# 2         Space Physics, Astronomy and Cosmology
# 3  Condensed Matter Physics and Material Science
# 4         Space Physics, Astronomy and Cosmology
#
#                                             Abstract  \
# 0  STUDY THE MECHANOCHEMISTRY OF SILICON CARBIDE ...
# 1  At Jefferson Lab we recently conducted an expe...
# 2  The present paper inspects the ionospheric res...
# 3  Wide range of investigation is going on to stu...
# 4  Interstellar space is not empty, but contains ...
#
#                            Title of the Presentation Presentation Method
# 0  STUDY THE MECHANOCHEMISTRY OF SILICON CARBIDE ...                 NAN
# 1                       EMC ratios in Lighter Nuclei                 NAN
# 2  Comparative study of GPS-TEC and IRI-2016 TEC ...                 NAN
# 3  First Principles Investigation on the Electron...                 NAN
# 4  Electronic Structure Calculation  Of Some Inte...                 NAN

# %%
template = '''
<!-- ########################################################################## -->

<table id="customers">
 
<tr>
    <th>Time</th>
    <td>8:12 PM - 8:24 AM EST</td>
  </tr>
<tr>
    <th>Author/s</th>
    <td>Agrima Nana Shrestha, Yenca Migoya Orue
</td>
    
  </tr>
<tr>
    <th>Title</th>
    <td>Comparative study of GPS-TEC and IRI-2016 TEC during total solar eclipse of 22 July, 2009 over Nepal

</td>
    
  </tr>
<tr>
    <th>Affiliation/s</th>
    <td> 1. ASCOL Campus, (TU), Nepal <br /> (2) ICTP
</td>
  
  </tr>
<tr>
    <th>Abstract</th>
    <td>"The present paper inspects the ionospheric response in terms of Total Electron Content (TEC) during the Total Solar Eclipse of 22 July 2009. The ionospheric behaviour was investigated through the changes in TEC by using the data archived at BRN2, RMTE, DNGD, NPGJ, and TPLJ Global Positioning System (GPS) stations. Our study is based on GPS-TEC measurements from a widely distributed GPS network over different geographical location of Nepal by taking July 17-21 as pre-event, July 22 as a main-event and July 23-27 as a post-event and its comparison with International Reference Ionosphere (IRI-2016) model to reveal the potential of IRI model in special events like solar eclipse with storm effect. The total solar eclipse of July 22, 2009, was totally visible from BRN2 and RMTE stations and partially visible from DNGD, NPGJ, and TPLJ stations. The result reveals that the amount of reduction in TEC is proportional to the magnitude of the total solar eclipse. The latitude also depends on the magnitude of the solar eclipse but the longitude doesn’t depend on it. The latitude is obtained to be directly proportional to the effect of the solar eclipse while longitude shows the inverse effect. TEC depletion up to 5% from pre-event to main-event and enhancement up to 30% from main-event to post-event were observed during the totality of the eclipse.The eclipse was followed by the geomagnetic storm all over Nepal which lasted for 10 hours which was the reason for the enhancement of TEC up to 50% in the main-event day from pre-event and post-event. It was also found that the IRI-2016 model underestimates the GPS-TEC and doesn’t seem to be effective for a particular event.

"

</td>
   
  </tr>
</table>
<br />
<br />
<!-- ########################################################################## -->

'''

print (template)
# Out:
# <!-- ########################################################################## -->
#
# <table id="customers">
#
# <tr>
#     <th>Time</th>
#     <td>8:12 PM - 8:24 AM EST</td>
#   </tr>
# <tr>
#     <th>Author/s</th>
#     <td>Agrima Nana Shrestha, Yenca Migoya Orue
# </td>
#
#   </tr>
# <tr>
#     <th>Title</th>
#     <td>Comparative study of GPS-TEC and IRI-2016 TEC during total solar eclipse of 22 July, 2009 over Nepal
#
# </td>
#
#   </tr>
# <tr>
#     <th>Affiliation/s</th>
#     <td> 1. ASCOL Campus, (TU), Nepal <br /> (2) ICTP
# </td>
#
#   </tr>
# <tr>
#     <th>Abstract</th>
#     <td>"The present paper inspects the ionospheric response in terms of Total Electron Content (TEC) during the Total Solar Eclipse of 22 July 2009. The ionospheric behaviour was investigated through the changes in TEC by using the data archived at BRN2, RMTE, DNGD, NPGJ, and TPLJ Global Positioning System (GPS) stations. Our study is based on GPS-TEC measurements from a widely distributed GPS network over different geographical location of Nepal by taking July 17-21 as pre-event, July 22 as a main-event and July 23-27 as a post-event and its comparison with International Reference Ionosphere (IRI-2016) model to reveal the potential of IRI model in special events like solar eclipse with storm effect. The total solar eclipse of July 22, 2009, was totally visible from BRN2 and RMTE stations and partially visible from DNGD, NPGJ, and TPLJ stations. The result reveals that the amount of reduction in TEC is proportional to the magnitude of the total solar eclipse. The latitude also depends on the magnitude of the solar eclipse but the longitude doesn’t depend on it. The latitude is obtained to be directly proportional to the effect of the solar eclipse while longitude shows the inverse effect. TEC depletion up to 5% from pre-event to main-event and enhancement up to 30% from main-event to post-event were observed during the totality of the eclipse.The eclipse was followed by the geomagnetic storm all over Nepal which lasted for 10 hours which was the reason for the enhancement of TEC up to 50% in the main-event day from pre-event and post-event. It was also found that the IRI-2016 model underestimates the GPS-TEC and doesn’t seem to be effective for a particular event.
#
# "
#
# </td>
#
#   </tr>
# </table>
# <br />
# <br />
# <!-- ########################################################################## -->

# %%
authors_ = 'Agrima Nana Shrestha, Yenca Migoya Orue'
title_ = 'Comparative study of GPS-TEC and IRI-2016 TEC during total solar eclipse of 22 July, 2009 over Nepal'
affiliations_ = ' 1. ASCOL Campus, (TU), Nepal (2) ICTP'
abstract_ = "The present paper inspects the ionospheric response in terms of Total Electron Content (TEC) during the Total Solar Eclipse of 22 July 2009. The ionospheric behaviour was investigated through the changes in TEC by using the data archived at BRN2, RMTE, DNGD, NPGJ, and TPLJ Global Positioning System (GPS) stations. Our study is based on GPS-TEC measurements from a widely distributed GPS network over different geographical location of Nepal by taking July 17-21 as pre-event, July 22 as a main-event and July 23-27 as a post-event and its comparison with International Reference Ionosphere (IRI-2016) model to reveal the potential of IRI model in special events like solar eclipse with storm effect. The total solar eclipse of July 22, 2009, was totally visible from BRN2 and RMTE stations and partially visible from DNGD, NPGJ, and TPLJ stations. The result reveals that the amount of reduction in TEC is proportional to the magnitude of the total solar eclipse. The latitude also depends on the magnitude of the solar eclipse but the longitude doesn’t depend on it. The latitude is obtained to be directly proportional to the effect of the solar eclipse while longitude shows the inverse effect. TEC depletion up to 5% from pre-event to main-event and enhancement up to 30% from main-event to post-event were observed during the totality of the eclipse.The eclipse was followed by the geomagnetic storm all over Nepal which lasted for 10 hours which was the reason for the enhancement of TEC up to 50% in the main-event day from pre-event and post-event. It was also found that the IRI-2016 model underestimates the GPS-TEC and doesn’t seem to be effective for a particular event."

template = '''
<!-- ########################################################################## -->

<table id="customers">
 
<tr>
    <th>Time</th>
    <td>8:12 PM - 8:24 AM EST</td>
  </tr>
<tr>
    <th>Author/s</th>
    <td>{authors_}
</td>
    
  </tr>
<tr>
    <th>Title</th>
    <td>{title_}

</td>
    
  </tr>
<tr>
    <th>Affiliation/s</th>
    <td>{affiliations_}
</td>
  
  </tr>
<tr>
    <th>Abstract</th>
    <td>" {abstract_} "

</td>
   
  </tr>
</table>
<br />
<br />


'''.format(authors_=authors_, title_ = title_, affiliations_ = affiliations_, abstract_ = abstract_ )




print (template)
# Out:
# <!-- ########################################################################## -->
#
# <table id="customers">
#
# <tr>
#     <th>Time</th>
#     <td>8:12 PM - 8:24 AM EST</td>
#   </tr>
# <tr>
#     <th>Author/s</th>
#     <td>Agrima Nana Shrestha, Yenca Migoya Orue
# </td>
#
#   </tr>
# <tr>
#     <th>Title</th>
#     <td>Comparative study of GPS-TEC and IRI-2016 TEC during total solar eclipse of 22 July, 2009 over Nepal
#
# </td>
#
#   </tr>
# <tr>
#     <th>Affiliation/s</th>
#     <td> 1. ASCOL Campus, (TU), Nepal (2) ICTP
# </td>
#
#   </tr>
# <tr>
#     <th>Abstract</th>
#     <td>" The present paper inspects the ionospheric response in terms of Total Electron Content (TEC) during the Total Solar Eclipse of 22 July 2009. The ionospheric behaviour was investigated through the changes in TEC by using the data archived at BRN2, RMTE, DNGD, NPGJ, and TPLJ Global Positioning System (GPS) stations. Our study is based on GPS-TEC measurements from a widely distributed GPS network over different geographical location of Nepal by taking July 17-21 as pre-event, July 22 as a main-event and July 23-27 as a post-event and its comparison with International Reference Ionosphere (IRI-2016) model to reveal the potential of IRI model in special events like solar eclipse with storm effect. The total solar eclipse of July 22, 2009, was totally visible from BRN2 and RMTE stations and partially visible from DNGD, NPGJ, and TPLJ stations. The result reveals that the amount of reduction in TEC is proportional to the magnitude of the total solar eclipse. The latitude also depends on the magnitude of the solar eclipse but the longitude doesn’t depend on it. The latitude is obtained to be directly proportional to the effect of the solar eclipse while longitude shows the inverse effect. TEC depletion up to 5% from pre-event to main-event and enhancement up to 30% from main-event to post-event were observed during the totality of the eclipse.The eclipse was followed by the geomagnetic storm all over Nepal which lasted for 10 hours which was the reason for the enhancement of TEC up to 50% in the main-event day from pre-event and post-event. It was also found that the IRI-2016 model underestimates the GPS-TEC and doesn’t seem to be effective for a particular event. "
#
# </td>
#
#   </tr>
# </table>
# <br />
# <br />

# %%
authors_L = ['Agrima Nana Shrestha, Yenca Migoya Orue']
title_L = ['Comparative study of GPS-TEC and IRI-2016 TEC during total solar eclipse of 22 July, 2009 over Nepal']
affiliations_L = [' 1. ASCOL Campus, (TU), Nepal (2) ICTP']
abstract_L = ["The present paper inspects the ionospheric response in terms of Total Electron Content (TEC) during the Total Solar Eclipse of 22 July 2009. The ionospheric behaviour was investigated through the changes in TEC by using the data archived at BRN2, RMTE, DNGD, NPGJ, and TPLJ Global Positioning System (GPS) stations. Our study is based on GPS-TEC measurements from a widely distributed GPS network over different geographical location of Nepal by taking July 17-21 as pre-event, July 22 as a main-event and July 23-27 as a post-event and its comparison with International Reference Ionosphere (IRI-2016) model to reveal the potential of IRI model in special events like solar eclipse with storm effect. The total solar eclipse of July 22, 2009, was totally visible from BRN2 and RMTE stations and partially visible from DNGD, NPGJ, and TPLJ stations. The result reveals that the amount of reduction in TEC is proportional to the magnitude of the total solar eclipse. The latitude also depends on the magnitude of the solar eclipse but the longitude doesn’t depend on it. The latitude is obtained to be directly proportional to the effect of the solar eclipse while longitude shows the inverse effect. TEC depletion up to 5% from pre-event to main-event and enhancement up to 30% from main-event to post-event were observed during the totality of the eclipse.The eclipse was followed by the geomagnetic storm all over Nepal which lasted for 10 hours which was the reason for the enhancement of TEC up to 50% in the main-event day from pre-event and post-event. It was also found that the IRI-2016 model underestimates the GPS-TEC and doesn’t seem to be effective for a particular event."]

for i in range(1):
    
    authors_ = authors_L[i]
    title_ = title_L[i]
    affiliations_ = affiliations_L[i]
    abstract_ = abstract_L[i]
    

    template = '''
<!-- ########################################################################## -->

<table id="customers">

<tr>
    <th>Time</th>
    <td>8:12 PM - 8:24 AM EST</td>
  </tr>
<tr>
    <th>Author/s</th>
    <td>{authors_}
</td>

  </tr>
<tr>
    <th>Title</th>
    <td>{title_}

</td>

  </tr>
<tr>
    <th>Affiliation/s</th>
    <td>{affiliations_}
</td>

  </tr>
<tr>
    <th>Abstract</th>
    <td>" {abstract_} "

</td>

  </tr>
</table>
<br />
<br />


'''.format(authors_=authors_, title_ = title_, affiliations_ = affiliations_, abstract_ = abstract_ )


    print (template)
# Out:
# <!-- ########################################################################## -->
#
# <table id="customers">
#
# <tr>
#     <th>Time</th>
#     <td>8:12 PM - 8:24 AM EST</td>
#   </tr>
# <tr>
#     <th>Author/s</th>
#     <td>Agrima Nana Shrestha, Yenca Migoya Orue
# </td>
#
#   </tr>
# <tr>
#     <th>Title</th>
#     <td>Comparative study of GPS-TEC and IRI-2016 TEC during total solar eclipse of 22 July, 2009 over Nepal
#
# </td>
#
#   </tr>
# <tr>
#     <th>Affiliation/s</th>
#     <td> 1. ASCOL Campus, (TU), Nepal (2) ICTP
# </td>
#
#   </tr>
# <tr>
#     <th>Abstract</th>
#     <td>" The present paper inspects the ionospheric response in terms of Total Electron Content (TEC) during the Total Solar Eclipse of 22 July 2009. The ionospheric behaviour was investigated through the changes in TEC by using the data archived at BRN2, RMTE, DNGD, NPGJ, and TPLJ Global Positioning System (GPS) stations. Our study is based on GPS-TEC measurements from a widely distributed GPS network over different geographical location of Nepal by taking July 17-21 as pre-event, July 22 as a main-event and July 23-27 as a post-event and its comparison with International Reference Ionosphere (IRI-2016) model to reveal the potential of IRI model in special events like solar eclipse with storm effect. The total solar eclipse of July 22, 2009, was totally visible from BRN2 and RMTE stations and partially visible from DNGD, NPGJ, and TPLJ stations. The result reveals that the amount of reduction in TEC is proportional to the magnitude of the total solar eclipse. The latitude also depends on the magnitude of the solar eclipse but the longitude doesn’t depend on it. The latitude is obtained to be directly proportional to the effect of the solar eclipse while longitude shows the inverse effect. TEC depletion up to 5% from pre-event to main-event and enhancement up to 30% from main-event to post-event were observed during the totality of the eclipse.The eclipse was followed by the geomagnetic storm all over Nepal which lasted for 10 hours which was the reason for the enhancement of TEC up to 50% in the main-event day from pre-event and post-event. It was also found that the IRI-2016 model underestimates the GPS-TEC and doesn’t seem to be effective for a particular event. "
#
# </td>
#
#   </tr>
# </table>
# <br />
# <br />

# %%
df.head(1)
# Out:
#                 Timestamp              Email Address        Full Name  \
# 0 2020-05-31 22:14:04.112  abiskarsubedi16@gmail.com  Aabiskar Subedi
#
#                        Current Affiliation Phone Number      Author List   \
# 0    Prithivi Naryan Campus , M.Sc Physics   9846781416  Aabiskar Subedi
#
#      Author Affiliation/s  \
# 0  PrithiviNaryan Campus
#
#   What part of your information and presentation can we upload on our website?  \
# 0  Author Name/s; Title of the Presentation and A...
#
#   Do you want to publish your research in extended abstract/proceedings? If you answer 'Yes' and our selection committee approves, we will contact you later.   \
# 0                                                Yes
#
#   We are planning to live telecast this event for authors who consent to it. Do you consent to live telecast your presentation?   \
# 0                                                Yes
#
#         Please choose field of your presentation  \
# 0  Condensed Matter Physics and Material Science
#
#                                             Abstract  \
# 0  STUDY THE MECHANOCHEMISTRY OF SILICON CARBIDE ...
#
#                            Title of the Presentation Presentation Method
# 0  STUDY THE MECHANOCHEMISTRY OF SILICON CARBIDE ...                 NAN

# %%
df.columns
# Out:
# Index(['Timestamp', 'Email Address', 'Full Name', 'Current Affiliation',
#        'Phone Number', 'Author List ', 'Author Affiliation/s',
#        'What part of your information and presentation can we upload on our website?',
#        'Do you want to publish your research in extended abstract/proceedings? If you answer 'Yes' and our selection committee approves, we will contact you later. ',
#        'We are planning to live telecast this event for authors who consent to it. Do you consent to live telecast your presentation? ',
#        'Please choose field of your presentation', 'Abstract',
#        'Title of the Presentation', 'Presentation Method'],
#       dtype='object')

# %%
Names_L = df['Full Name'].values
authors_L = df['Author List '].values
title_L = df['Title of the Presentation'].values
affiliations_L = df['Author Affiliation/s'].values
abstract_L = df['Abstract'].values

# %%
authors_L[5]
# Out:
# 'Suman Acharya and Gopi Chandra Kafle'

# %%
print (Names_L[0] )
Names_L[0] in authors_L[0]
# Out:
# Aabiskar Subedi
# True

# %%
fo = open('html_code2.html', 'w')
for i in range(len(authors_L)):
#for i in range(3):
    names_ = Names_L[i]
    authors_ = authors_L[i]
    title_ = title_L[i]
    affiliations_ = affiliations_L[i]
    abstract_ = abstract_L[i]
    
    #if names_ not in authors_:
    if (authors_ == 'NAN'):
        authors_updated = names_
    elif (names_ in authors_ ):
        authors_updated = names_
    else:
        authors_updated = names_ + ' ' +authors_
        
    print (str(names_), str(authors_)) # 
    print ( 'updated:', authors_updated )
   


    html_code = '''
<!-- ########################################################################## -->

<table id="customers">

<tr>
    <th>Time</th>
    <td>8:12 PM - 8:24 AM EST</td>
  </tr>
<tr>
    <th>Author/s</th>
    <td>{authors_}
</td>

  </tr>
<tr>
    <th>Title</th>
    <td>{title_}

</td>

  </tr>
<tr>
    <th>Affiliation/s</th>
    <td>{affiliations_}
</td>

  </tr>
<tr>
    <th>Abstract</th>
    <td>" {abstract_} "

</td>

  </tr>
</table>
<br />
<br />


'''.format(authors_=authors_updated, title_ = title_, affiliations_ = affiliations_, abstract_ = abstract_ )

    fo.write(html_code)
# Out:
# Aabiskar Subedi Aabiskar Subedi
# updated: Aabiskar Subedi
# Abishek Karki NAN
# updated: Abishek Karki
# Agrima Nana Shrestha Yenca Migoya Orue
# updated: Agrima Nana Shrestha Yenca Migoya Orue
# Alisha Budhathoki Madhav Prasad Ghimire
# updated: Alisha Budhathoki Madhav Prasad Ghimire
# Alisha Paudel Aabiskar Bhusal
# updated: Alisha Paudel Aabiskar Bhusal
# Alok Lal Karn Suman Acharya and Gopi Chandra Kafle
# updated: Alok Lal Karn Suman Acharya and Gopi Chandra Kafle
# Aman Ganeju Dibakar Sigdel
# updated: Aman Ganeju Dibakar Sigdel
# Amba Datt Pant TBA
# updated: Amba Datt Pant TBA
# Angel Bashyal Aayush Gautam
# Suman Satyal
# Shree Krishna Bhattarai
# updated: Angel Bashyal Aayush Gautam
# Suman Satyal
# Shree Krishna Bhattarai
# Anish Maskey Anish Maskey, Atit Deuja, Suresh Basnet, Raju Khanal
# updated: Anish Maskey
# Anita Mishra Anita Mishra,  Anish Maskey, Atit Deuja, Denish Poudyal and Raju Khanal
# updated: Anita Mishra
# Anjila Ghimire Dr Rishi Ram Ghimire,  Anjilla Ghimire
# updated: Anjila Ghimire Dr Rishi Ram Ghimire,  Anjilla Ghimire
# Sujan Prasad Gautam Binil Aryal & Ashok Silwal & Amrit Sedain
# updated: Sujan Prasad Gautam Binil Aryal & Ashok Silwal & Amrit Sedain
# Suresh Basnet Atit Deuja, Raju Khanal
# updated: Suresh Basnet Atit Deuja, Raju Khanal
# Suresh Bhattarai NAN
# updated: Suresh Bhattarai
# Suresh Paudyal Dr. Gopi chandra kaphle
# updated: Suresh Paudyal Dr. Gopi chandra kaphle
# Swapnil Baral Lars Gundlach, Bjoern Baumeier, Edward Lyman
# updated: Swapnil Baral Lars Gundlach, Bjoern Baumeier, Edward Lyman
# Tarani Prasad Yadav 1. Dr. Gopi Chandra Kaphle
# 2. Dr. Anurag Srivastava
# updated: Tarani Prasad Yadav 1. Dr. Gopi Chandra Kaphle
# 2. Dr. Anurag Srivastava
# Tej B. Limbu Tej B. Limbu,† Basant Chitara,† Jason D. Orlando,† Martha Y. Garcia Cervantes,† Shalini Kumari,∥ Qi Li,∥ Yongan Tang,‡ Fei Yan*, †
# updated: Tej B. Limbu
# Thakur Bhandari Thakur Bhandari and Gopi Chandra Kaphle
# updated: Thakur Bhandari
# Umesh Silwal U. Silwal1, S. V. Ilyushkin2, J. A. Winger2, K. P. Rykaczewski3, C. J. Gross3, J. C. Batchelder4, L. Cartegni5, I. G. Darby5,6, R. Grzywacz3,5, J. H Hamilton7, A. Korgul5,7,8,9, W. Krolas9,10, S. N. Liddick5,11, C. Mazzocchi5,8,12, T. Mendez3, S. Padgett5, M. M Rajabali5,6, D. Shapira3, D. W. Stracener3, and E. F. Zganjar13
# updated: Umesh Silwal U. Silwal1, S. V. Ilyushkin2, J. A. Winger2, K. P. Rykaczewski3, C. J. Gross3, J. C. Batchelder4, L. Cartegni5, I. G. Darby5,6, R. Grzywacz3,5, J. H Hamilton7, A. Korgul5,7,8,9, W. Krolas9,10, S. N. Liddick5,11, C. Mazzocchi5,8,12, T. Mendez3, S. Padgett5, M. M Rajabali5,6, D. Shapira3, D. W. Stracener3, and E. F. Zganjar13
# USHA JOSHI Prof. Dr. Khem Narayan Poudyal,
# Prof. Dr. Indra Bahadur Karki,
# Prof. Dr. Narayan Prasad Chapagain
# updated: USHA JOSHI Prof. Dr. Khem Narayan Poudyal,
# Prof. Dr. Indra Bahadur Karki,
# Prof. Dr. Narayan Prasad Chapagain
# Utsav Siwakoti U. Siwakoti, D. R. Upadhyay, H. K. Neupane
# updated: Utsav Siwakoti U. Siwakoti, D. R. Upadhyay, H. K. Neupane
# Yogendra Limbu Niraj Shah, Gopi Chandra Kaphle
# updated: Yogendra Limbu Niraj Shah, Gopi Chandra Kaphle
# Youbraj Paudel Youbraj Paudel & Gopi Chandra Kaphle
# updated: Youbraj Paudel

# %%
x1=['a', 'b', 'c', 'd', 'e']
x2=[1, 2, 3, 4, 5]
x3=['a1', 'b1', 'c1', 'd1', 'e1']

dff= pd.DataFrame({'x1':x1, 'x2':x2, 'x3':x3})

# %%
#dff[x1].append(dff[x3])

# %%
x1=['a', 'b', 'c', 'd', 'e']

x1.insert(0, 'x')

x1
# Out:
# ['x', 'a', 'b', 'c', 'd', 'e']
